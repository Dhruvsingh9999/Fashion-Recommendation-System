# %%
import os
from tqdm import tqdm
import pickle
import tensorflow as tf

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input
import numpy as np
from numpy.linalg import norm

# %%
base_model = EfficientNetB0(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = False
model = tf.keras.Sequential([
    base_model,
    GlobalMaxPooling2D()
])

print(model.summary())
# Out:
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 1280)           │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,049,571 (15.45 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 4,049,571 (15.45 MB)
# None

# %%
def extract_features(img_path, model):
    img = load_img(img_path, target_size=(224, 224))
    img_array = img_to_array(img)
    expanded_img_array = np.expand_dims(img_array, axis=0)
    preprocess_img = preprocess_input(expanded_img_array)
    result = model.predict(preprocess_img).flatten()
    normalized_result = result / norm(result)
    return normalized_result

# %%
import os
image_dir = r"D:/Programming/Project/Fashion Recommendation System/images"
if not os.path.exists(image_dir):
    print("Error: 'images' directory not found!")
    exit()

# %%
import os
import pickle
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.resnet50 import preprocess_input
import numpy as np
from numpy.linalg import norm
from tqdm import tqdm
from features_extractor import extract_features  # Ensure this file exists in the same directory

# Define image directory (Make sure to set the correct path)
image_dir = "D:\Programming\Project\Fashion Recommendation System\images"

# Get a list of all image filenames
filenames = [os.path.join(image_dir, file) for file in os.listdir(image_dir) if file.endswith(('jpg', 'png', 'jpeg'))]

# Extract features for each image
features_list = []
for file in tqdm(filenames, desc="Extracting Features"):
    features_list.append(extract_features(file))

# Save extracted features and filenames
with open("embeddings.pkl", "wb") as f:
    pickle.dump(features_list, f)

with open("filenames.pkl", "wb") as f:
    pickle.dump(filenames, f)

print("Feature extraction completed successfully!")
# Out:
# Extracting Features:   0%|          | 0/2906 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Extracting Features:   0%|          | 1/2906 [00:01<59:40,  1.23s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting Features:   0%|          | 2/2906 [00:01<32:41,  1.48it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting Features:   0%|          | 3/2906 [00:01<24:27,  1.98it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Extracting Features:   0%|          | 4/2906 [00:02<19:07,  2.53it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# Extracting Features:   0%|          | 5/2906 [00:02<19:46,  2.45it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Extracting Features:   0%|          | 6/2906 [00:02<20:23,  2.37it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Extracting Features:   0%|          | 7/2906 [00:03<22:30,  2.15it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Extracting Features:   0%|          | 8/2906 [00:04<24:12,  2.00it/s]
# ...
